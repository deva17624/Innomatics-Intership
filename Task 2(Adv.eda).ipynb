# %% [markdown]
# ## Defanging an IP Address

# %%
class Solution(object):
    def defangIPaddr(self, address):
        s=""

        for i in address:
            if i==".":
                s=s+"[.]"
            else:
                s=s+i
        return s

# %%
sol=Solution()
print(sol.defangIPaddr("1.1.1.1"))
# Out:
# 1[.]1[.]1[.]1

# %% [markdown]
# ## Find Numbers with Even Number of Digits

# %%
class Solution(object):
    def findNumbers(self, nums):
        n=0
        for i in nums:
            a=0
            while(i!=0):
                i=i//10
                a=a+1
            if a!=0 and a%2==0:
                n=n+1
        return n

# %%
sol=Solution()
sol.findNumbers([12,345,2,6,7896])
# Out:
# 2

# %% [markdown]
# ## Number of Good Pairs

# %%
class Solution(object):
    def numIdenticalPairs(self, nums):
        l=[]
        for i in range(len(nums)):
            for j in range(i+1,len(nums)):
                if nums[i]==nums[j]:
                    l.append((i,j))
        return len(l)

# %%
sol=Solution()
sol.numIdenticalPairs([1,2,3,1,1,3])
# Out:
# 4

# %% [markdown]
# ## How Many Numbers Are Smaller Than the Current Number

# %%
class Solution(object):
    def smallerNumbersThanCurrent(self, nums):
        l=[]
        for i in range(len(nums)):
            n=0
            for j in range(len(nums)):
                if nums[i]>nums[j]:
                    n=n+1
            l.append(n)
        return l

# %%
sol=Solution()
sol.smallerNumbersThanCurrent([8,1,2,2,3])
# Out:
# [4, 0, 1, 1, 3]

# %% [markdown]
# ## Subtract the Product and Sum of Digits of an Integer

# %%
class Solution(object):
    def subtractProductAndSum(self, n):
        add=0
        mul=1
        while(n!=0):
            a=n%10
            add=add+a
            mul=mul*a
            n=n//10
        return mul-add

# %%
sol=Solution()
sol.subtractProductAndSum(234)
# Out:
# 15

# %% [markdown]
# ## XOR Operation in an Array

# %%
class Solution(object):
    def xorOperation(self, n, start):
        result = 0
        for i in range(n):
            result = result ^ (start + 2 * i)
        return result

# %%
sol=Solution()
sol.xorOperation(5,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 sol=Solution()
# ----> 2 sol.xorOperation()
#
# TypeError: Solution.xorOperation() missing 2 required positional arguments: 'n' and 'start'
